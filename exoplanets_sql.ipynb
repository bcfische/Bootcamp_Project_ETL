# %% [markdown]
# Project Description
#
# For this project, we are interested in habitable (i.e. Earth-like) planets that exist outside our solar system.
# One source of information is provided by the Planetary Habitability Laboratory, which maintains the Habitable
# Exoplanets Catalog. Our idea is to combine this dataset with one from Kaggle, namely the Exoplanets Database,
# which is a database of all confirmed exoplanets ever discovered, from all planet-hunting missions. Our goal is
# to find the exoplanets that exist in both databases and create a new SQL database. Comments are provided in each
# cell to outline how we accomplished this.
#
# One side note: the PHL website contains two data tables of interest, which sort of summarize the catalog. Our idea
# was to scrape these tables as a means of getting the data, and not have to solely rely on CSV files. This however
# proved to be a very challenging exercise, as the HTML code was difficult to parse. In the end, a relatively simple
# copy/paste into Excel ended up being the method we used to get the habitable planet information.

# %%
# Dependencies
import pandas as pd
from sqlalchemy import create_engine

# %%
# Reading datasource 1
# https://www.kaggle.com/eduardowoj/exoplanets-database
# It contains data from missions like Kepler, CoRoT, and OGLE, as well as from other means of detection, like direct imaging
exoplanets = pd.read_csv('kepler.csv')

# %%
# Printing columns for data source 1
for col in exoplanets.columns: 
    print(col)
# Out:
# # name
# planet_status
# mass
# mass_error_min
# mass_error_max
# mass_sini
# mass_sini_error_min
# mass_sini_error_max
# radius
# radius_error_min
# radius_error_max
# orbital_period
# orbital_period_error_min
# orbital_period_error_max
# semi_major_axis
# semi_major_axis_error_min
# semi_major_axis_error_max
# eccentricity
# eccentricity_error_min
# eccentricity_error_max
# inclination
# inclination_error_min
# inclination_error_max
# angular_distance
# discovered
# updated
# omega
# omega_error_min
# omega_error_max
# tperi
# tperi_error_min
# tperi_error_max
# tconj
# tconj_error_min
# tconj_error_max
# tzero_tr
# tzero_tr_error_min
# tzero_tr_error_max
# tzero_tr_sec
# tzero_tr_sec_error_min
# tzero_tr_sec_error_max
# lambda_angle
# lambda_angle_error_min
# lambda_angle_error_max
# impact_parameter
# impact_parameter_error_min
# impact_parameter_error_max
# tzero_vr
# tzero_vr_error_min
# tzero_vr_error_max
# k
# k_error_min
# k_error_max
# temp_calculated
# temp_calculated_error_min
# temp_calculated_error_max
# temp_measured
# hot_point_lon
# geometric_albedo
# geometric_albedo_error_min
# geometric_albedo_error_max
# log_g
# publication_status
# detection_type
# mass_detection_type
# radius_detection_type
# alternate_names
# molecules
# star_name
# ra
# dec
# mag_v
# mag_i
# mag_j
# mag_h
# mag_k
# star_distance
# star_distance_error_min
# star_distance_error_max
# star_metallicity
# star_metallicity_error_min
# star_metallicity_error_max
# star_mass
# star_mass_error_min
# star_mass_error_max
# star_radius
# star_radius_error_min
# star_radius_error_max
# star_sp_type
# star_age
# star_age_error_min
# star_age_error_max
# star_teff
# star_teff_error_min
# star_teff_error_max
# star_detected_disc
# star_magnetic_field
# star_alternate_names

# %%
# Renaming column [0] to match other datasources
exoplanets.rename(columns={'# name': 'name'}, inplace=True)
exoplanets
# Out:
#                         name planet_status      mass  mass_error_min  \
# 0      OGLE-2016-BLG-1469L b     Confirmed  13.60000         3.00000
# 1                   11 Com b     Confirmed  19.40000         1.50000
# 2                   11 Oph b     Confirmed  21.00000         3.00000
# 3                   11 UMi b     Confirmed  10.50000         2.47000
# 4                   14 And b     Confirmed   5.33000         0.57000
# 5                   14 Her b     Confirmed   4.64000         0.19000
# 6                 16 Cyg B b     Confirmed   1.68000         0.07000
# 7                   18 Del b     Confirmed  10.30000             NaN
# 8                 1I/2017 U1     Confirmed       NaN             NaN
# 9                1RXS 1609 b     Confirmed  14.00000         3.00000
# 10            1SWASP J1407 b     Confirmed  20.00000         6.00000
# 11                  24 Sex b     Confirmed   1.99000         0.38000
# 12                  24 Sex c     Confirmed   0.86000         0.22000
# 13         2M 0103-55 (AB) b     Confirmed  13.00000         1.00000
# 14              2M 0122-24 b     Confirmed  20.00000         7.00000
# 15              2M 0219-39 b     Confirmed  13.90000         1.10000
# 16              2M 0441+23 b     Confirmed   7.50000         2.50000
# 17              2M 0746+20 b     Confirmed  30.00000        25.00000
# 18                2M 1207-39     Confirmed  24.00000         6.00000
# 19              2M 1207-39 b     Confirmed   4.00000         1.00000
# 20              2M 1938+46 b     Confirmed   1.90000         0.10000
# 21              2M 2140+16 b     Confirmed  20.00000        20.00000
# 22              2M 2206-20 b     Confirmed  30.00000        20.00000
# 23            2M 2236+4751 b     Confirmed  12.50000         1.50000
# 24             2M J2126-81 b     Confirmed  13.30000         1.70000
# 25           2M1450-7841 B b     Confirmed   0.04000             NaN
# 26             2M1450-7841 b     Confirmed   0.04000             NaN
# 27               2M2250+2325     Confirmed  30.00000         4.00000
# 28        2MASS J11193254 AB     Confirmed   3.70000         0.90000
# 29                30 Ari B b     Confirmed   9.88000         0.94000
# ...                      ...           ...       ...             ...
# 3702               eps Tau b     Confirmed   7.34000         0.40000
# 3703               eta Cet b     Confirmed   2.55000         0.13000
# 3704               eta Cet c     Confirmed   3.32000         0.18000
# 3705           gamma 1 Leo b     Confirmed  63.90000        56.10000
# 3706          gamma Cephei b     Confirmed  11.10000         4.40000
# 3707             kappa And b     Confirmed  14.00000         2.00000
# 3708             kappa CrB b     Confirmed   1.60000             NaN
# 3709             kepler-80 g     Confirmed       NaN             NaN
# 3710               ksi Aql b     Confirmed   2.02000         0.20000
# 3711                mu Ara b     Confirmed   1.67600             NaN
# 3712                mu Ara c     Confirmed   0.03321             NaN
# 3713                mu Ara d     Confirmed   0.52190             NaN
# 3714                mu Ara e     Confirmed   1.81400             NaN
# 3715                mu Leo b     Confirmed   2.40000         0.40000
# 3716                nu Oph b     Confirmed  24.00000             NaN
# 3717                nu Oph c     Confirmed  27.00000             NaN
# 3718               ome Ser b     Confirmed   1.70000             NaN
# 3719               omi CrB b     Confirmed   1.50000             NaN
# 3720               omi UMa b     Confirmed   4.10000             NaN
# 3721               sig Per b     Confirmed   6.50000         1.00000
# 3722               tau Boo b     Confirmed   5.84000         0.55200
# 3723               tau Cet e     Confirmed   0.01240         0.00200
# 3724               tau Cet f     Confirmed   0.01240         0.00431
# 3725               tau Cet g     Confirmed   0.00551         0.00130
# 3726               tau Cet h     Confirmed   0.00576         0.00082
# 3727               tau Gem b     Confirmed  20.60000             NaN
# 3728               ups And b     Confirmed   0.62000         0.09000
# 3729               ups And c     Confirmed   9.10000         2.90000
# 3730               ups And d     Confirmed  23.58000         2.29500
# 3731               ups And e     Confirmed   1.05900         0.02800
#
#       mass_error_max  mass_sini  mass_sini_error_min  mass_sini_error_max  \
# 0           3.000000        NaN                  NaN                  NaN
# 1           1.500000   19.40000              1.50000              1.50000
# 2           3.000000        NaN                  NaN                  NaN
# 3           2.470000   10.50000              2.47000              2.47000
# 4           0.570000    5.33000              0.57000              0.57000
# 5           0.190000    4.64000              0.19000              0.19000
# 6           0.070000    1.68000              0.07000              0.07000
# 7                NaN   10.30000                  NaN                  NaN
# 8                NaN        NaN                  NaN                  NaN
# 9           2.000000        NaN                  NaN                  NaN
# 10          6.000000   20.00000              6.00000              6.00000
# 11          0.260000    1.99000              0.38000              0.26000
# 12          0.350000    0.86000              0.22000              0.35000
# 13          1.000000        NaN                  NaN                  NaN
# 14          7.000000        NaN                  NaN                  NaN
# 15          1.100000        NaN                  NaN                  NaN
# 16          2.500000        NaN                  NaN                  NaN
# 17         25.000000        NaN                  NaN                  NaN
# 18          6.000000        NaN                  NaN                  NaN
# 19          1.000000        NaN                  NaN                  NaN
# 20          0.100000        NaN                  NaN                  NaN
# 21         80.000000        NaN                  NaN                  NaN
# 22         70.000000        NaN                  NaN                  NaN
# 23          1.500000        NaN                  NaN                  NaN
# 24          1.700000        NaN                  NaN                  NaN
# 25               NaN        NaN                  NaN                  NaN
# 26               NaN        NaN                  NaN                  NaN
# 27         11.000000        NaN                  NaN                  NaN
# 28          1.200000        NaN                  NaN                  NaN
# 29          0.940000    9.88000              0.94000              0.94000
# ...              ...        ...                  ...                  ...
# 3702        0.500000    7.34000              0.40000              0.50000
# 3703        0.130000    2.55000              0.13000              0.13000
# 3704        0.180000    3.32000              0.18000              0.18000
# 3705       72.900000    8.78000              1.00000              1.00000
# 3706       18.500000    1.85000              0.06000              0.06000
# 3707       25.000000        NaN                  NaN                  NaN
# 3708             NaN    1.60000                  NaN                  NaN
# 3709             NaN        NaN                  NaN                  NaN
# 3710        0.200000    2.02000              0.20000              0.20000
# 3711             NaN    1.67600                  NaN                  NaN
# 3712             NaN    0.03321                  NaN                  NaN
# 3713             NaN    0.52190                  NaN                  NaN
# 3714             NaN    1.81400                  NaN                  NaN
# 3715        0.400000    2.40000              0.40000              0.40000
# 3716             NaN   24.00000                  NaN                  NaN
# 3717             NaN   27.00000                  NaN                  NaN
# 3718             NaN    1.70000                  NaN                  NaN
# 3719             NaN    1.50000                  NaN                  NaN
# 3720             NaN    4.10000                  NaN                  NaN
# 3721        1.000000    6.50000              1.00000              1.00000
# 3722        0.988000    4.13000              0.20000              0.35000
# 3723        0.002600    0.01240              0.00200              0.00260
# 3724        0.003300    0.01240              0.00431              0.00330
# 3725        0.000790    0.00551              0.00130              0.00079
# 3726        0.002100    0.00576              0.00082              0.00210
# 3727             NaN   20.60000                  NaN                  NaN
# 3728             inf    0.62000              0.09000              0.09000
# 3729        5.000000    1.80000              0.26000              0.26000
# 3730        2.931000   10.19000                  NaN                  NaN
# 3731        0.028000    1.05900              0.02800              0.02800
#
#         radius  radius_error_min  \
# 0          NaN               NaN
# 1          NaN               NaN
# 2          NaN               NaN
# 3          NaN               NaN
# 4          NaN               NaN
# 5          NaN               NaN
# 6          NaN               NaN
# 7          NaN               NaN
# 8     0.000002               NaN
# 9     1.700000               NaN
# 10         NaN               NaN
# 11         NaN               NaN
# 12         NaN               NaN
# 13         NaN               NaN
# 14    1.000000             0.200
# 15    1.440000             0.030
# 16         NaN               NaN
# 17    0.970000             0.060
# 18         NaN               NaN
# 19         NaN               NaN
# 20         NaN               NaN
# 21    0.920000             0.390
# 22    1.300000             0.180
# 23         NaN               NaN
# 24         NaN               NaN
# 25         NaN               NaN
# 26         NaN               NaN
# 27         NaN               NaN
# 28         NaN               NaN
# 29         NaN               NaN
# ...        ...               ...
# 3702       NaN               NaN
# 3703       NaN               NaN
# 3704       NaN               NaN
# 3705       NaN               NaN
# 3706       NaN               NaN
# 3707  1.200000             0.100
# 3708       NaN               NaN
# 3709  0.101000             0.012
# 3710       NaN               NaN
# 3711       NaN               NaN
# 3712       NaN               NaN
# 3713       NaN               NaN
# 3714       NaN               NaN
# 3715       NaN               NaN
# 3716       NaN               NaN
# 3717       NaN               NaN
# 3718       NaN               NaN
# 3719       NaN               NaN
# 3720       NaN               NaN
# 3721       NaN               NaN
# 3722  1.060000               NaN
# 3723       NaN               NaN
# 3724       NaN               NaN
# 3725       NaN               NaN
# 3726       NaN               NaN
# 3727       NaN               NaN
# 3728       NaN               NaN
# 3729       NaN               NaN
# 3730       NaN               NaN
# 3731       NaN               NaN
#
#                           ...                        star_sp_type  star_age  \
# 0                         ...                                 NaN       NaN
# 1                         ...                              G8 III       NaN
# 2                         ...                                  M9     0.011
# 3                         ...                               K4III     1.560
# 4                         ...                               K0III       NaN
# 5                         ...                                K0 V     5.100
# 6                         ...                              G2.5 V     8.000
# 7                         ...                               G6III       NaN
# 8                         ...                                 NaN       NaN
# 9                         ...                                 K7V     0.011
# 10                        ...                                 NaN     0.016
# 11                        ...                                  G5     2.700
# 12                        ...                                  G5     2.700
# 13                        ...                                   M     0.030
# 14                        ...                                M3.5     0.120
# 15                        ...                                  M6       NaN
# 16                        ...                                M8.5     0.001
# 17                        ...                                 NaN       NaN
# 18                        ...                                  M8     0.008
# 19                        ...                                  M8     0.008
# 20                        ...                               sdB+M       NaN
# 21                        ...                                 NaN       NaN
# 22                        ...                                 NaN       NaN
# 23                        ...                                  K7     0.120
# 24                        ...                                  M2     0.027
# 25                        ...                                 NaN     0.040
# 26                        ...                                 NaN     0.040
# 27                        ...                                  M3     0.150
# 28                        ...                                  L7     0.010
# 29                        ...                                 F6V     0.910
# ...                       ...                                 ...       ...
# 3702                      ...                              K0 III     0.625
# 3703                      ...                               K1III       NaN
# 3704                      ...                               K1III       NaN
# 3705                      ...                               K0III       NaN
# 3706                      ...                            K1III-IV     6.600
# 3707                      ...                                B9IV     0.030
# 3708                      ...                               K1IVa     2.500
# 3709                      ...                                 NaN       NaN
# 3710                      ...                              G9IIIb       NaN
# 3711                      ...                             G3 IV-V     6.410
# 3712                      ...                             G3 IV-V     6.410
# 3713                      ...                             G3 IV-V     6.410
# 3714                      ...                             G3 IV-V     6.410
# 3715                      ...                               K2III     3.350
# 3716                      ...                               K0III       NaN
# 3717                      ...                               K0III       NaN
# 3718                      ...                              G8 III       NaN
# 3719                      ...                               K0III       NaN
# 3720                      ...                            G4II-III       NaN
# 3721                      ...                               K3III       NaN
# 3722                      ...                                F7 V     2.520
# 3723                      ...                              G8.5 V     5.800
# 3724                      ...                              G8.5 V     5.800
# 3725                      ...                              G8.5 V     5.800
# 3726                      ...                              G8.5 V     5.800
# 3727                      ...                               K2III     1.220
# 3728                      ...                                F8 V     3.800
# 3729                      ...                                F8 V     3.800
# 3730                      ...                                F8 V     3.800
# 3731                      ...                                F8 V     3.800
#
#       star_age_error_min  star_age_error_max  star_teff  star_teff_error_min  \
# 0                    NaN                 NaN        NaN                  NaN
# 1                    NaN                 NaN     4742.0                100.0
# 2                  0.002               0.002     2375.0                175.0
# 3                  0.540               0.540     4340.0                 70.0
# 4                    NaN                 NaN     4813.0                 20.0
# 5                    NaN                 NaN     5311.0                 87.0
# 6                  1.800               1.800     5766.0                 60.0
# 7                    NaN                 NaN     4979.0                 18.0
# 8                    NaN                 NaN        NaN                  NaN
# 9                  0.002               0.002     4060.0                200.0
# 10                   NaN                 NaN     4400.0                100.0
# 11                 0.400               0.400     5098.0                 44.0
# 12                 0.400               0.400     5098.0                 44.0
# 13                   NaN                 NaN        NaN                  NaN
# 14                 0.010               0.010        NaN                  NaN
# 15                   NaN                 NaN     3064.0                 76.0
# 16                   NaN                 NaN        NaN                  NaN
# 17                   NaN                 NaN     2205.0                 50.0
# 18                 0.003               0.003        NaN                  NaN
# 19                 0.003               0.003        NaN                  NaN
# 20                   NaN                 NaN        NaN                  NaN
# 21                   NaN                 NaN     2300.0                 80.0
# 22                   NaN                 NaN     2350.0                 80.0
# 23                 0.010               0.010        NaN                  NaN
# 24                 0.017               0.017        NaN                  NaN
# 25                   NaN                 NaN        NaN                  NaN
# 26                   NaN                 NaN        NaN                  NaN
# 27                   NaN                 NaN        NaN                  NaN
# 28                 0.003               0.003        NaN                  NaN
# 29                 0.030               0.030     6484.0                 98.0
# ...                  ...                 ...        ...                  ...
# 3702               0.050               0.050     4901.0                 20.0
# 3703                 NaN                 NaN     4528.0                 19.0
# 3704                 NaN                 NaN     4528.0                 19.0
# 3705                 NaN                 NaN     4330.0                 15.0
# 3706                 NaN                 NaN     4800.0                100.0
# 3707               0.010               0.120    11361.0                 66.0
# 3708               1.000               1.000     4960.0                 70.0
# 3709                 NaN                 NaN     4250.0                  NaN
# 3710                 NaN                 NaN     4780.0                 30.0
# 3711                 NaN                 NaN     5700.0                100.0
# 3712                 NaN                 NaN     5700.0                100.0
# 3713                 NaN                 NaN     5700.0                100.0
# 3714                 NaN                 NaN     5700.0                100.0
# 3715               0.700               0.700     4538.2                 27.5
# 3716                 NaN                 NaN     4928.0                 25.0
# 3717                 NaN                 NaN     4928.0                 25.0
# 3718                 NaN                 NaN     4770.0                 10.0
# 3719                 NaN                 NaN     4749.0                 20.0
# 3720                 NaN                 NaN     5242.0                 10.0
# 3721                 NaN                 NaN     4367.0                100.0
# 3722                 NaN                 NaN     6309.0                  NaN
# 3723                 NaN                 NaN     5344.0                 50.0
# 3724                 NaN                 NaN     5344.0                 50.0
# 3725                 NaN                 NaN     5344.0                 50.0
# 3726                 NaN                 NaN     5344.0                 50.0
# 3727               0.760               0.760     4388.0                 25.0
# 3728               1.000               1.000     6212.0                 80.0
# 3729               1.000               1.000     6212.0                 80.0
# 3730               1.000               1.000     6212.0                 80.0
# 3731               1.000               1.000     6212.0                 80.0
#
#       star_teff_error_max  star_detected_disc  star_magnetic_field  \
# 0                     NaN                 NaN                  NaN
# 1                   100.0                 NaN                  NaN
# 2                   175.0                 NaN                  NaN
# 3                    70.0                 NaN                  NaN
# 4                    20.0                 NaN                  NaN
# 5                    87.0                 NaN                  NaN
# 6                    60.0                 NaN                  NaN
# 7                    18.0                 NaN                  NaN
# 8                     NaN                 NaN                  NaN
# 9                   200.0                 NaN                  NaN
# 10                  100.0                 NaN                  NaN
# 11                   44.0                 NaN                  NaN
# 12                   44.0                 NaN                  NaN
# 13                    NaN                 NaN                  NaN
# 14                    NaN                 NaN                  NaN
# 15                   76.0                 NaN                  NaN
# 16                    NaN                 NaN                  NaN
# 17                   50.0                 NaN                  NaN
# 18                    NaN                 NaN                  NaN
# 19                    NaN                 NaN                  NaN
# 20                    NaN                 NaN                  NaN
# 21                   80.0                 NaN                  NaN
# 22                   80.0                 NaN                  NaN
# 23                    NaN                 NaN                  NaN
# 24                    NaN                 NaN                  NaN
# 25                    NaN                 NaN                  NaN
# 26                    NaN                 NaN                  NaN
# 27                    NaN                 NaN                  NaN
# 28                    NaN                 NaN                  NaN
# 29                   98.0                 NaN                  NaN
# ...                   ...                 ...                  ...
# 3702                 20.0                 NaN                  NaN
# 3703                 19.0                 NaN                  NaN
# 3704                 19.0                 NaN                  NaN
# 3705                 15.0                 NaN                  NaN
# 3706                100.0                 NaN                  NaN
# 3707                 66.0                 NaN                  NaN
# 3708                 70.0                 NaN                  NaN
# 3709                  NaN                 NaN                  NaN
# 3710                 30.0                 NaN                  NaN
# 3711                100.0                 NaN                  NaN
# 3712                100.0                 NaN                  NaN
# 3713                100.0                 NaN                  NaN
# 3714                100.0                 NaN                  NaN
# 3715                 27.5                 NaN                  NaN
# 3716                 25.0                 NaN                  NaN
# 3717                 25.0                 NaN                  NaN
# 3718                 10.0                 NaN                  NaN
# 3719                 20.0                 NaN                  NaN
# 3720                 10.0                 NaN                  NaN
# 3721                100.0                 NaN                  NaN
# 3722                  NaN                 NaN                  NaN
# 3723                 50.0             Imaging                  NaN
# 3724                 50.0             Imaging                  NaN
# 3725                 50.0             Imaging                  NaN
# 3726                 50.0             Imaging                  NaN
# 3727                 25.0                 NaN                  NaN
# 3728                 80.0                 NaN                  NaN
# 3729                 80.0                 NaN                  NaN
# 3730                 80.0                 NaN                  NaN
# 3731                 80.0                 NaN                  NaN
#
#                                star_alternate_names
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
# 6                                               NaN
# 7                                               NaN
# 8                                               NaN
# 9                                               NaN
# 10                                              NaN
# 11                                              NaN
# 12                                              NaN
# 13                                              NaN
# 14                                              NaN
# 15                           2MASS J0292210-3925225
# 16                                              NaN
# 17                                              NaN
# 18                                              NaN
# 19                                              NaN
# 20                                       Kepler-451
# 21                                              NaN
# 22                                              NaN
# 23                                              NaN
# 24                                              NaN
# 25                                              NaN
# 26                                              NaN
# 27                                              NaN
# 28                                              NaN
# 29                                              NaN
# ...                                             ...
# 3702                               HD 28305, 74 Tau
# 3703                                            NaN
# 3704                                            NaN
# 3705                                            NaN
# 3706                                            NaN
# 3707  19 Andromedae, HIP 116805, HR 8976, HD 222439
# 3708                                            NaN
# 3709                                        KOI-500
# 3710                    HD 188310, 59 Aql, Libertas
# 3711                                            NaN
# 3712                                            NaN
# 3713                                            NaN
# 3714                                            NaN
# 3715                                            NaN
# 3716                                            NaN
# 3717                                            NaN
# 3718                                            NaN
# 3719                                            NaN
# 3720                                            NaN
# 3721                                            NaN
# 3722                                            NaN
# 3723                                            NaN
# 3724                                            NaN
# 3725                                            NaN
# 3726                                            NaN
# 3727                                            NaN
# 3728                                            NaN
# 3729                                            NaN
# 3730                                            NaN
# 3731                                            NaN
#
# [3732 rows x 98 columns]

# %%
exoplanets.set_index('name', inplace=True)
exoplanets
# Out:
#                        planet_status      mass  mass_error_min  \
# name
#  OGLE-2016-BLG-1469L b     Confirmed  13.60000         3.00000
# 11 Com b                   Confirmed  19.40000         1.50000
# 11 Oph b                   Confirmed  21.00000         3.00000
# 11 UMi b                   Confirmed  10.50000         2.47000
# 14 And b                   Confirmed   5.33000         0.57000
# 14 Her b                   Confirmed   4.64000         0.19000
# 16 Cyg B b                 Confirmed   1.68000         0.07000
# 18 Del b                   Confirmed  10.30000             NaN
# 1I/2017 U1                 Confirmed       NaN             NaN
# 1RXS 1609 b                Confirmed  14.00000         3.00000
# 1SWASP J1407 b             Confirmed  20.00000         6.00000
# 24 Sex b                   Confirmed   1.99000         0.38000
# 24 Sex c                   Confirmed   0.86000         0.22000
# 2M 0103-55 (AB) b          Confirmed  13.00000         1.00000
# 2M 0122-24 b               Confirmed  20.00000         7.00000
# 2M 0219-39 b               Confirmed  13.90000         1.10000
# 2M 0441+23 b               Confirmed   7.50000         2.50000
# 2M 0746+20 b               Confirmed  30.00000        25.00000
# 2M 1207-39                 Confirmed  24.00000         6.00000
# 2M 1207-39 b               Confirmed   4.00000         1.00000
# 2M 1938+46 b               Confirmed   1.90000         0.10000
# 2M 2140+16 b               Confirmed  20.00000        20.00000
# 2M 2206-20 b               Confirmed  30.00000        20.00000
# 2M 2236+4751 b             Confirmed  12.50000         1.50000
# 2M J2126-81 b              Confirmed  13.30000         1.70000
# 2M1450-7841 B b            Confirmed   0.04000             NaN
# 2M1450-7841 b              Confirmed   0.04000             NaN
# 2M2250+2325                Confirmed  30.00000         4.00000
# 2MASS J11193254 AB         Confirmed   3.70000         0.90000
# 30 Ari B b                 Confirmed   9.88000         0.94000
# ...                              ...       ...             ...
# eps Tau b                  Confirmed   7.34000         0.40000
# eta Cet b                  Confirmed   2.55000         0.13000
# eta Cet c                  Confirmed   3.32000         0.18000
# gamma 1 Leo b              Confirmed  63.90000        56.10000
# gamma Cephei b             Confirmed  11.10000         4.40000
# kappa And b                Confirmed  14.00000         2.00000
# kappa CrB b                Confirmed   1.60000             NaN
# kepler-80 g                Confirmed       NaN             NaN
# ksi Aql b                  Confirmed   2.02000         0.20000
# mu Ara b                   Confirmed   1.67600             NaN
# mu Ara c                   Confirmed   0.03321             NaN
# mu Ara d                   Confirmed   0.52190             NaN
# mu Ara e                   Confirmed   1.81400             NaN
# mu Leo b                   Confirmed   2.40000         0.40000
# nu Oph b                   Confirmed  24.00000             NaN
# nu Oph c                   Confirmed  27.00000             NaN
# ome Ser b                  Confirmed   1.70000             NaN
# omi CrB b                  Confirmed   1.50000             NaN
# omi UMa b                  Confirmed   4.10000             NaN
# sig Per b                  Confirmed   6.50000         1.00000
# tau Boo b                  Confirmed   5.84000         0.55200
# tau Cet e                  Confirmed   0.01240         0.00200
# tau Cet f                  Confirmed   0.01240         0.00431
# tau Cet g                  Confirmed   0.00551         0.00130
# tau Cet h                  Confirmed   0.00576         0.00082
# tau Gem b                  Confirmed  20.60000             NaN
# ups And b                  Confirmed   0.62000         0.09000
# ups And c                  Confirmed   9.10000         2.90000
# ups And d                  Confirmed  23.58000         2.29500
# ups And e                  Confirmed   1.05900         0.02800
#
#                         mass_error_max  mass_sini  mass_sini_error_min  \
# name
#  OGLE-2016-BLG-1469L b        3.000000        NaN                  NaN
# 11 Com b                      1.500000   19.40000              1.50000
# 11 Oph b                      3.000000        NaN                  NaN
# 11 UMi b                      2.470000   10.50000              2.47000
# 14 And b                      0.570000    5.33000              0.57000
# 14 Her b                      0.190000    4.64000              0.19000
# 16 Cyg B b                    0.070000    1.68000              0.07000
# 18 Del b                           NaN   10.30000                  NaN
# 1I/2017 U1                         NaN        NaN                  NaN
# 1RXS 1609 b                   2.000000        NaN                  NaN
# 1SWASP J1407 b                6.000000   20.00000              6.00000
# 24 Sex b                      0.260000    1.99000              0.38000
# 24 Sex c                      0.350000    0.86000              0.22000
# 2M 0103-55 (AB) b             1.000000        NaN                  NaN
# 2M 0122-24 b                  7.000000        NaN                  NaN
# 2M 0219-39 b                  1.100000        NaN                  NaN
# 2M 0441+23 b                  2.500000        NaN                  NaN
# 2M 0746+20 b                 25.000000        NaN                  NaN
# 2M 1207-39                    6.000000        NaN                  NaN
# 2M 1207-39 b                  1.000000        NaN                  NaN
# 2M 1938+46 b                  0.100000        NaN                  NaN
# 2M 2140+16 b                 80.000000        NaN                  NaN
# 2M 2206-20 b                 70.000000        NaN                  NaN
# 2M 2236+4751 b                1.500000        NaN                  NaN
# 2M J2126-81 b                 1.700000        NaN                  NaN
# 2M1450-7841 B b                    NaN        NaN                  NaN
# 2M1450-7841 b                      NaN        NaN                  NaN
# 2M2250+2325                  11.000000        NaN                  NaN
# 2MASS J11193254 AB            1.200000        NaN                  NaN
# 30 Ari B b                    0.940000    9.88000              0.94000
# ...                                ...        ...                  ...
# eps Tau b                     0.500000    7.34000              0.40000
# eta Cet b                     0.130000    2.55000              0.13000
# eta Cet c                     0.180000    3.32000              0.18000
# gamma 1 Leo b                72.900000    8.78000              1.00000
# gamma Cephei b               18.500000    1.85000              0.06000
# kappa And b                  25.000000        NaN                  NaN
# kappa CrB b                        NaN    1.60000                  NaN
# kepler-80 g                        NaN        NaN                  NaN
# ksi Aql b                     0.200000    2.02000              0.20000
# mu Ara b                           NaN    1.67600                  NaN
# mu Ara c                           NaN    0.03321                  NaN
# mu Ara d                           NaN    0.52190                  NaN
# mu Ara e                           NaN    1.81400                  NaN
# mu Leo b                      0.400000    2.40000              0.40000
# nu Oph b                           NaN   24.00000                  NaN
# nu Oph c                           NaN   27.00000                  NaN
# ome Ser b                          NaN    1.70000                  NaN
# omi CrB b                          NaN    1.50000                  NaN
# omi UMa b                          NaN    4.10000                  NaN
# sig Per b                     1.000000    6.50000              1.00000
# tau Boo b                     0.988000    4.13000              0.20000
# tau Cet e                     0.002600    0.01240              0.00200
# tau Cet f                     0.003300    0.01240              0.00431
# tau Cet g                     0.000790    0.00551              0.00130
# tau Cet h                     0.002100    0.00576              0.00082
# tau Gem b                          NaN   20.60000                  NaN
# ups And b                          inf    0.62000              0.09000
# ups And c                     5.000000    1.80000              0.26000
# ups And d                     2.931000   10.19000                  NaN
# ups And e                     0.028000    1.05900              0.02800
#
#                         mass_sini_error_max    radius  radius_error_min  \
# name
#  OGLE-2016-BLG-1469L b                  NaN       NaN               NaN
# 11 Com b                            1.50000       NaN               NaN
# 11 Oph b                                NaN       NaN               NaN
# 11 UMi b                            2.47000       NaN               NaN
# 14 And b                            0.57000       NaN               NaN
# 14 Her b                            0.19000       NaN               NaN
# 16 Cyg B b                          0.07000       NaN               NaN
# 18 Del b                                NaN       NaN               NaN
# 1I/2017 U1                              NaN  0.000002               NaN
# 1RXS 1609 b                             NaN  1.700000               NaN
# 1SWASP J1407 b                      6.00000       NaN               NaN
# 24 Sex b                            0.26000       NaN               NaN
# 24 Sex c                            0.35000       NaN               NaN
# 2M 0103-55 (AB) b                       NaN       NaN               NaN
# 2M 0122-24 b                            NaN  1.000000             0.200
# 2M 0219-39 b                            NaN  1.440000             0.030
# 2M 0441+23 b                            NaN       NaN               NaN
# 2M 0746+20 b                            NaN  0.970000             0.060
# 2M 1207-39                              NaN       NaN               NaN
# 2M 1207-39 b                            NaN       NaN               NaN
# 2M 1938+46 b                            NaN       NaN               NaN
# 2M 2140+16 b                            NaN  0.920000             0.390
# 2M 2206-20 b                            NaN  1.300000             0.180
# 2M 2236+4751 b                          NaN       NaN               NaN
# 2M J2126-81 b                           NaN       NaN               NaN
# 2M1450-7841 B b                         NaN       NaN               NaN
# 2M1450-7841 b                           NaN       NaN               NaN
# 2M2250+2325                             NaN       NaN               NaN
# 2MASS J11193254 AB                      NaN       NaN               NaN
# 30 Ari B b                          0.94000       NaN               NaN
# ...                                     ...       ...               ...
# eps Tau b                           0.50000       NaN               NaN
# eta Cet b                           0.13000       NaN               NaN
# eta Cet c                           0.18000       NaN               NaN
# gamma 1 Leo b                       1.00000       NaN               NaN
# gamma Cephei b                      0.06000       NaN               NaN
# kappa And b                             NaN  1.200000             0.100
# kappa CrB b                             NaN       NaN               NaN
# kepler-80 g                             NaN  0.101000             0.012
# ksi Aql b                           0.20000       NaN               NaN
# mu Ara b                                NaN       NaN               NaN
# mu Ara c                                NaN       NaN               NaN
# mu Ara d                                NaN       NaN               NaN
# mu Ara e                                NaN       NaN               NaN
# mu Leo b                            0.40000       NaN               NaN
# nu Oph b                                NaN       NaN               NaN
# nu Oph c                                NaN       NaN               NaN
# ome Ser b                               NaN       NaN               NaN
# omi CrB b                               NaN       NaN               NaN
# omi UMa b                               NaN       NaN               NaN
# sig Per b                           1.00000       NaN               NaN
# tau Boo b                           0.35000  1.060000               NaN
# tau Cet e                           0.00260       NaN               NaN
# tau Cet f                           0.00330       NaN               NaN
# tau Cet g                           0.00079       NaN               NaN
# tau Cet h                           0.00210       NaN               NaN
# tau Gem b                               NaN       NaN               NaN
# ups And b                           0.09000       NaN               NaN
# ups And c                           0.26000       NaN               NaN
# ups And d                               NaN       NaN               NaN
# ups And e                           0.02800       NaN               NaN
#
#                         radius_error_max  \
# name
#  OGLE-2016-BLG-1469L b               NaN
# 11 Com b                             NaN
# 11 Oph b                             NaN
# 11 UMi b                             NaN
# 14 And b                             NaN
# 14 Her b                             NaN
# 16 Cyg B b                           NaN
# 18 Del b                             NaN
# 1I/2017 U1                           NaN
# 1RXS 1609 b                          NaN
# 1SWASP J1407 b                       NaN
# 24 Sex b                             NaN
# 24 Sex c                             NaN
# 2M 0103-55 (AB) b                    NaN
# 2M 0122-24 b                       0.200
# 2M 0219-39 b                       0.030
# 2M 0441+23 b                         NaN
# 2M 0746+20 b                       0.060
# 2M 1207-39                           NaN
# 2M 1207-39 b                         NaN
# 2M 1938+46 b                         NaN
# 2M 2140+16 b                       0.390
# 2M 2206-20 b                       0.180
# 2M 2236+4751 b                       NaN
# 2M J2126-81 b                        NaN
# 2M1450-7841 B b                      NaN
# 2M1450-7841 b                        NaN
# 2M2250+2325                          NaN
# 2MASS J11193254 AB                   NaN
# 30 Ari B b                           NaN
# ...                                  ...
# eps Tau b                            NaN
# eta Cet b                            NaN
# eta Cet c                            NaN
# gamma 1 Leo b                        NaN
# gamma Cephei b                       NaN
# kappa And b                        0.200
# kappa CrB b                          NaN
# kepler-80 g                        0.012
# ksi Aql b                            NaN
# mu Ara b                             NaN
# mu Ara c                             NaN
# mu Ara d                             NaN
# mu Ara e                             NaN
# mu Leo b                             NaN
# nu Oph b                             NaN
# nu Oph c                             NaN
# ome Ser b                            NaN
# omi CrB b                            NaN
# omi UMa b                            NaN
# sig Per b                            NaN
# tau Boo b                            NaN
# tau Cet e                            NaN
# tau Cet f                            NaN
# tau Cet g                            NaN
# tau Cet h                            NaN
# tau Gem b                            NaN
# ups And b                            NaN
# ups And c                            NaN
# ups And d                            NaN
# ups And e                            NaN
#
#                                             ...                        \
# name                                        ...
#  OGLE-2016-BLG-1469L b                      ...
# 11 Com b                                    ...
# 11 Oph b                                    ...
# 11 UMi b                                    ...
# 14 And b                                    ...
# 14 Her b                                    ...
# 16 Cyg B b                                  ...
# 18 Del b                                    ...
# 1I/2017 U1                                  ...
# 1RXS 1609 b                                 ...
# 1SWASP J1407 b                              ...
# 24 Sex b                                    ...
# 24 Sex c                                    ...
# 2M 0103-55 (AB) b                           ...
# 2M 0122-24 b                                ...
# 2M 0219-39 b                                ...
# 2M 0441+23 b                                ...
# 2M 0746+20 b                                ...
# 2M 1207-39                                  ...
# 2M 1207-39 b                                ...
# 2M 1938+46 b                                ...
# 2M 2140+16 b                                ...
# 2M 2206-20 b                                ...
# 2M 2236+4751 b                              ...
# 2M J2126-81 b                               ...
# 2M1450-7841 B b                             ...
# 2M1450-7841 b                               ...
# 2M2250+2325                                 ...
# 2MASS J11193254 AB                          ...
# 30 Ari B b                                  ...
# ...                                         ...
# eps Tau b                                   ...
# eta Cet b                                   ...
# eta Cet c                                   ...
# gamma 1 Leo b                               ...
# gamma Cephei b                              ...
# kappa And b                                 ...
# kappa CrB b                                 ...
# kepler-80 g                                 ...
# ksi Aql b                                   ...
# mu Ara b                                    ...
# mu Ara c                                    ...
# mu Ara d                                    ...
# mu Ara e                                    ...
# mu Leo b                                    ...
# nu Oph b                                    ...
# nu Oph c                                    ...
# ome Ser b                                   ...
# omi CrB b                                   ...
# omi UMa b                                   ...
# sig Per b                                   ...
# tau Boo b                                   ...
# tau Cet e                                   ...
# tau Cet f                                   ...
# tau Cet g                                   ...
# tau Cet h                                   ...
# tau Gem b                                   ...
# ups And b                                   ...
# ups And c                                   ...
# ups And d                                   ...
# ups And e                                   ...
#
#                         star_sp_type  star_age  star_age_error_min  \
# name
#  OGLE-2016-BLG-1469L b           NaN       NaN                 NaN
# 11 Com b                      G8 III       NaN                 NaN
# 11 Oph b                          M9     0.011               0.002
# 11 UMi b                       K4III     1.560               0.540
# 14 And b                       K0III       NaN                 NaN
# 14 Her b                        K0 V     5.100                 NaN
# 16 Cyg B b                    G2.5 V     8.000               1.800
# 18 Del b                       G6III       NaN                 NaN
# 1I/2017 U1                       NaN       NaN                 NaN
# 1RXS 1609 b                      K7V     0.011               0.002
# 1SWASP J1407 b                   NaN     0.016                 NaN
# 24 Sex b                          G5     2.700               0.400
# 24 Sex c                          G5     2.700               0.400
# 2M 0103-55 (AB) b                  M     0.030                 NaN
# 2M 0122-24 b                    M3.5     0.120               0.010
# 2M 0219-39 b                      M6       NaN                 NaN
# 2M 0441+23 b                    M8.5     0.001                 NaN
# 2M 0746+20 b                     NaN       NaN                 NaN
# 2M 1207-39                        M8     0.008               0.003
# 2M 1207-39 b                      M8     0.008               0.003
# 2M 1938+46 b                   sdB+M       NaN                 NaN
# 2M 2140+16 b                     NaN       NaN                 NaN
# 2M 2206-20 b                     NaN       NaN                 NaN
# 2M 2236+4751 b                    K7     0.120               0.010
# 2M J2126-81 b                     M2     0.027               0.017
# 2M1450-7841 B b                  NaN     0.040                 NaN
# 2M1450-7841 b                    NaN     0.040                 NaN
# 2M2250+2325                       M3     0.150                 NaN
# 2MASS J11193254 AB                L7     0.010               0.003
# 30 Ari B b                       F6V     0.910               0.030
# ...                              ...       ...                 ...
# eps Tau b                     K0 III     0.625               0.050
# eta Cet b                      K1III       NaN                 NaN
# eta Cet c                      K1III       NaN                 NaN
# gamma 1 Leo b                  K0III       NaN                 NaN
# gamma Cephei b              K1III-IV     6.600                 NaN
# kappa And b                     B9IV     0.030               0.010
# kappa CrB b                    K1IVa     2.500               1.000
# kepler-80 g                      NaN       NaN                 NaN
# ksi Aql b                     G9IIIb       NaN                 NaN
# mu Ara b                     G3 IV-V     6.410                 NaN
# mu Ara c                     G3 IV-V     6.410                 NaN
# mu Ara d                     G3 IV-V     6.410                 NaN
# mu Ara e                     G3 IV-V     6.410                 NaN
# mu Leo b                       K2III     3.350               0.700
# nu Oph b                       K0III       NaN                 NaN
# nu Oph c                       K0III       NaN                 NaN
# ome Ser b                     G8 III       NaN                 NaN
# omi CrB b                      K0III       NaN                 NaN
# omi UMa b                   G4II-III       NaN                 NaN
# sig Per b                      K3III       NaN                 NaN
# tau Boo b                       F7 V     2.520                 NaN
# tau Cet e                     G8.5 V     5.800                 NaN
# tau Cet f                     G8.5 V     5.800                 NaN
# tau Cet g                     G8.5 V     5.800                 NaN
# tau Cet h                     G8.5 V     5.800                 NaN
# tau Gem b                      K2III     1.220               0.760
# ups And b                       F8 V     3.800               1.000
# ups And c                       F8 V     3.800               1.000
# ups And d                       F8 V     3.800               1.000
# ups And e                       F8 V     3.800               1.000
#
#                         star_age_error_max  star_teff  star_teff_error_min  \
# name
#  OGLE-2016-BLG-1469L b                 NaN        NaN                  NaN
# 11 Com b                               NaN     4742.0                100.0
# 11 Oph b                             0.002     2375.0                175.0
# 11 UMi b                             0.540     4340.0                 70.0
# 14 And b                               NaN     4813.0                 20.0
# 14 Her b                               NaN     5311.0                 87.0
# 16 Cyg B b                           1.800     5766.0                 60.0
# 18 Del b                               NaN     4979.0                 18.0
# 1I/2017 U1                             NaN        NaN                  NaN
# 1RXS 1609 b                          0.002     4060.0                200.0
# 1SWASP J1407 b                         NaN     4400.0                100.0
# 24 Sex b                             0.400     5098.0                 44.0
# 24 Sex c                             0.400     5098.0                 44.0
# 2M 0103-55 (AB) b                      NaN        NaN                  NaN
# 2M 0122-24 b                         0.010        NaN                  NaN
# 2M 0219-39 b                           NaN     3064.0                 76.0
# 2M 0441+23 b                           NaN        NaN                  NaN
# 2M 0746+20 b                           NaN     2205.0                 50.0
# 2M 1207-39                           0.003        NaN                  NaN
# 2M 1207-39 b                         0.003        NaN                  NaN
# 2M 1938+46 b                           NaN        NaN                  NaN
# 2M 2140+16 b                           NaN     2300.0                 80.0
# 2M 2206-20 b                           NaN     2350.0                 80.0
# 2M 2236+4751 b                       0.010        NaN                  NaN
# 2M J2126-81 b                        0.017        NaN                  NaN
# 2M1450-7841 B b                        NaN        NaN                  NaN
# 2M1450-7841 b                          NaN        NaN                  NaN
# 2M2250+2325                            NaN        NaN                  NaN
# 2MASS J11193254 AB                   0.003        NaN                  NaN
# 30 Ari B b                           0.030     6484.0                 98.0
# ...                                    ...        ...                  ...
# eps Tau b                            0.050     4901.0                 20.0
# eta Cet b                              NaN     4528.0                 19.0
# eta Cet c                              NaN     4528.0                 19.0
# gamma 1 Leo b                          NaN     4330.0                 15.0
# gamma Cephei b                         NaN     4800.0                100.0
# kappa And b                          0.120    11361.0                 66.0
# kappa CrB b                          1.000     4960.0                 70.0
# kepler-80 g                            NaN     4250.0                  NaN
# ksi Aql b                              NaN     4780.0                 30.0
# mu Ara b                               NaN     5700.0                100.0
# mu Ara c                               NaN     5700.0                100.0
# mu Ara d                               NaN     5700.0                100.0
# mu Ara e                               NaN     5700.0                100.0
# mu Leo b                             0.700     4538.2                 27.5
# nu Oph b                               NaN     4928.0                 25.0
# nu Oph c                               NaN     4928.0                 25.0
# ome Ser b                              NaN     4770.0                 10.0
# omi CrB b                              NaN     4749.0                 20.0
# omi UMa b                              NaN     5242.0                 10.0
# sig Per b                              NaN     4367.0                100.0
# tau Boo b                              NaN     6309.0                  NaN
# tau Cet e                              NaN     5344.0                 50.0
# tau Cet f                              NaN     5344.0                 50.0
# tau Cet g                              NaN     5344.0                 50.0
# tau Cet h                              NaN     5344.0                 50.0
# tau Gem b                            0.760     4388.0                 25.0
# ups And b                            1.000     6212.0                 80.0
# ups And c                            1.000     6212.0                 80.0
# ups And d                            1.000     6212.0                 80.0
# ups And e                            1.000     6212.0                 80.0
#
#                         star_teff_error_max  star_detected_disc  \
# name
#  OGLE-2016-BLG-1469L b                  NaN                 NaN
# 11 Com b                              100.0                 NaN
# 11 Oph b                              175.0                 NaN
# 11 UMi b                               70.0                 NaN
# 14 And b                               20.0                 NaN
# 14 Her b                               87.0                 NaN
# 16 Cyg B b                             60.0                 NaN
# 18 Del b                               18.0                 NaN
# 1I/2017 U1                              NaN                 NaN
# 1RXS 1609 b                           200.0                 NaN
# 1SWASP J1407 b                        100.0                 NaN
# 24 Sex b                               44.0                 NaN
# 24 Sex c                               44.0                 NaN
# 2M 0103-55 (AB) b                       NaN                 NaN
# 2M 0122-24 b                            NaN                 NaN
# 2M 0219-39 b                           76.0                 NaN
# 2M 0441+23 b                            NaN                 NaN
# 2M 0746+20 b                           50.0                 NaN
# 2M 1207-39                              NaN                 NaN
# 2M 1207-39 b                            NaN                 NaN
# 2M 1938+46 b                            NaN                 NaN
# 2M 2140+16 b                           80.0                 NaN
# 2M 2206-20 b                           80.0                 NaN
# 2M 2236+4751 b                          NaN                 NaN
# 2M J2126-81 b                           NaN                 NaN
# 2M1450-7841 B b                         NaN                 NaN
# 2M1450-7841 b                           NaN                 NaN
# 2M2250+2325                             NaN                 NaN
# 2MASS J11193254 AB                      NaN                 NaN
# 30 Ari B b                             98.0                 NaN
# ...                                     ...                 ...
# eps Tau b                              20.0                 NaN
# eta Cet b                              19.0                 NaN
# eta Cet c                              19.0                 NaN
# gamma 1 Leo b                          15.0                 NaN
# gamma Cephei b                        100.0                 NaN
# kappa And b                            66.0                 NaN
# kappa CrB b                            70.0                 NaN
# kepler-80 g                             NaN                 NaN
# ksi Aql b                              30.0                 NaN
# mu Ara b                              100.0                 NaN
# mu Ara c                              100.0                 NaN
# mu Ara d                              100.0                 NaN
# mu Ara e                              100.0                 NaN
# mu Leo b                               27.5                 NaN
# nu Oph b                               25.0                 NaN
# nu Oph c                               25.0                 NaN
# ome Ser b                              10.0                 NaN
# omi CrB b                              20.0                 NaN
# omi UMa b                              10.0                 NaN
# sig Per b                             100.0                 NaN
# tau Boo b                               NaN                 NaN
# tau Cet e                              50.0             Imaging
# tau Cet f                              50.0             Imaging
# tau Cet g                              50.0             Imaging
# tau Cet h                              50.0             Imaging
# tau Gem b                              25.0                 NaN
# ups And b                              80.0                 NaN
# ups And c                              80.0                 NaN
# ups And d                              80.0                 NaN
# ups And e                              80.0                 NaN
#
#                         star_magnetic_field  \
# name
#  OGLE-2016-BLG-1469L b                  NaN
# 11 Com b                                NaN
# 11 Oph b                                NaN
# 11 UMi b                                NaN
# 14 And b                                NaN
# 14 Her b                                NaN
# 16 Cyg B b                              NaN
# 18 Del b                                NaN
# 1I/2017 U1                              NaN
# 1RXS 1609 b                             NaN
# 1SWASP J1407 b                          NaN
# 24 Sex b                                NaN
# 24 Sex c                                NaN
# 2M 0103-55 (AB) b                       NaN
# 2M 0122-24 b                            NaN
# 2M 0219-39 b                            NaN
# 2M 0441+23 b                            NaN
# 2M 0746+20 b                            NaN
# 2M 1207-39                              NaN
# 2M 1207-39 b                            NaN
# 2M 1938+46 b                            NaN
# 2M 2140+16 b                            NaN
# 2M 2206-20 b                            NaN
# 2M 2236+4751 b                          NaN
# 2M J2126-81 b                           NaN
# 2M1450-7841 B b                         NaN
# 2M1450-7841 b                           NaN
# 2M2250+2325                             NaN
# 2MASS J11193254 AB                      NaN
# 30 Ari B b                              NaN
# ...                                     ...
# eps Tau b                               NaN
# eta Cet b                               NaN
# eta Cet c                               NaN
# gamma 1 Leo b                           NaN
# gamma Cephei b                          NaN
# kappa And b                             NaN
# kappa CrB b                             NaN
# kepler-80 g                             NaN
# ksi Aql b                               NaN
# mu Ara b                                NaN
# mu Ara c                                NaN
# mu Ara d                                NaN
# mu Ara e                                NaN
# mu Leo b                                NaN
# nu Oph b                                NaN
# nu Oph c                                NaN
# ome Ser b                               NaN
# omi CrB b                               NaN
# omi UMa b                               NaN
# sig Per b                               NaN
# tau Boo b                               NaN
# tau Cet e                               NaN
# tau Cet f                               NaN
# tau Cet g                               NaN
# tau Cet h                               NaN
# tau Gem b                               NaN
# ups And b                               NaN
# ups And c                               NaN
# ups And d                               NaN
# ups And e                               NaN
#
#                                                  star_alternate_names
# name
#  OGLE-2016-BLG-1469L b                                            NaN
# 11 Com b                                                          NaN
# 11 Oph b                                                          NaN
# 11 UMi b                                                          NaN
# 14 And b                                                          NaN
# 14 Her b                                                          NaN
# 16 Cyg B b                                                        NaN
# 18 Del b                                                          NaN
# 1I/2017 U1                                                        NaN
# 1RXS 1609 b                                                       NaN
# 1SWASP J1407 b                                                    NaN
# 24 Sex b                                                          NaN
# 24 Sex c                                                          NaN
# 2M 0103-55 (AB) b                                                 NaN
# 2M 0122-24 b                                                      NaN
# 2M 0219-39 b                                   2MASS J0292210-3925225
# 2M 0441+23 b                                                      NaN
# 2M 0746+20 b                                                      NaN
# 2M 1207-39                                                        NaN
# 2M 1207-39 b                                                      NaN
# 2M 1938+46 b                                               Kepler-451
# 2M 2140+16 b                                                      NaN
# 2M 2206-20 b                                                      NaN
# 2M 2236+4751 b                                                    NaN
# 2M J2126-81 b                                                     NaN
# 2M1450-7841 B b                                                   NaN
# 2M1450-7841 b                                                     NaN
# 2M2250+2325                                                       NaN
# 2MASS J11193254 AB                                                NaN
# 30 Ari B b                                                        NaN
# ...                                                               ...
# eps Tau b                                            HD 28305, 74 Tau
# eta Cet b                                                         NaN
# eta Cet c                                                         NaN
# gamma 1 Leo b                                                     NaN
# gamma Cephei b                                                    NaN
# kappa And b             19 Andromedae, HIP 116805, HR 8976, HD 222439
# kappa CrB b                                                       NaN
# kepler-80 g                                                   KOI-500
# ksi Aql b                                 HD 188310, 59 Aql, Libertas
# mu Ara b                                                          NaN
# mu Ara c                                                          NaN
# mu Ara d                                                          NaN
# mu Ara e                                                          NaN
# mu Leo b                                                          NaN
# nu Oph b                                                          NaN
# nu Oph c                                                          NaN
# ome Ser b                                                         NaN
# omi CrB b                                                         NaN
# omi UMa b                                                         NaN
# sig Per b                                                         NaN
# tau Boo b                                                         NaN
# tau Cet e                                                         NaN
# tau Cet f                                                         NaN
# tau Cet g                                                         NaN
# tau Cet h                                                         NaN
# tau Gem b                                                         NaN
# ups And b                                                         NaN
# ups And c                                                         NaN
# ups And d                                                         NaN
# ups And e                                                         NaN
#
# [3732 rows x 97 columns]

# %%
# Reading datasource 2
# http://phl.upr.edu/projects/habitable-exoplanets-catalog/data
# Table A-2 Optimistic sample of potentially habitable planets
# These are potentially habitable exoplanets discovered by different ground or space observatories
a2 = pd.read_csv('table_a2.csv')

# %%
# Reading datasource 3
# http://phl.upr.edu/projects/habitable-exoplanets-catalog/data
# Table K-2 Kepler (Q1-Q17 DR 24) optimistic sample of potentially habitable planets
# These are exoplanets discovered by the NASA Kepler primary mission
k2 = pd.read_csv('table_k2.csv')

# %%
# Concatenating datasources 2 and 3
habitables = pd.concat([a2, k2])
habitables
# Out:
#                   name                type               mass  \
# 0    001. TRAPPIST-1 d    M-Warm Subterran                0.4
# 1       002. GJ 3323 b       M-Warm Terran                  2
# 2    003. Kepler-438 b       M-Warm Terran    4.0 - 1.3 - 0.6
# 3      004. Ross 128 b       M-Warm Terran                1.4
# 4        005. GJ 273 b       M-Warm Terran                2.9
# 5    006. Kepler-296 e       M-Warm Terran   12.5 - 3.3 - 1.4
# 6     007. Kepler-62 e  K-Warm Superterran   18.7 - 4.5 - 1.9
# 7    008. Kepler-452 b  G-Warm Superterran   19.8 - 4.7 - 1.9
# 8         009. K2-72 e       M-Warm Terran    9.8 - 2.7 - 1.2
# 9     010. Wolf 1061 c       M-Warm Terran                3.4
# 10       011. GJ 832 c  M-Warm Superterran                5.4
# 11         012. K2-3 d       M-Warm Terran               11.1
# 12  013. Kepler-1544 b  K-Warm Superterran   31.7 - 6.6 - 2.6
# 13   014. Kepler-283 c  K-Warm Superterran   35.3 - 7.0 - 2.8
# 14     015. tau Cet e*       G-Warm Terran                4.3
# 15  016. Kepler-1410 b  K-Warm Superterran   31.7 - 6.6 - 2.6
# 16      017. GJ 180 c*  M-Warm Superterran                6.4
# 17   018. HD 283869 b*  K-Warm Superterran   59.2 - 9.5 - 3.7
# 18  019. Kepler-1638 b  G-Warm Superterran   42.7 - 7.9 - 3.1
# 19   020. Kepler-440 b  K-Warm Superterran   41.2 - 7.7 - 3.1
# 20      021. GJ 180 b*  M-Warm Superterran                8.3
# 21   022. Kepler-705 b  M-Warm Superterran     ? - 12.7 - 4.8
# 22    023. HD 40307 g*  K-Warm Superterran                7.1
# 23       024. GJ 163 c  M-Warm Superterran                7.3
# 24    025. Kepler-61 b  K-Warm Superterran     ? - 13.8 - 5.2
# 25        026. K2-18 b  M-Warm Superterran     ? - 16.5 - 6.0
# 26  027. Kepler-1606 b  G-Warm Superterran     ? - 11.9 - 4.5
# 27  028. Kepler-1090 b  G-Warm Superterran     ? - 16.8 - 6.1
# 28   029. Kepler-443 b  K-Warm Superterran     ? - 19.5 - 7.0
# 29    030. Kepler-22 b  G-Warm Superterran     ? - 20.4 - 7.2
# ..                 ...                 ...                ...
# 21   022. KOI-4054.01*  G-Warm Superterran  67.2 - 10.1 - 3.9
# 22   023. KOI-5202.01*  F-Warm Superterran   37.2 - 7.3 - 2.9
# 23   024. KOI-7587.01*  G-Warm Superterran     ? - 14.9 - 5.5
# 24   025. KOI-1871.01*  K-Warm Superterran     ? - 13.8 - 5.2
# 25    026. Kepler-22 b  G-Warm Superterran     ? - 14.4 - 5.4
# 26   027. Kepler-443 b  K-Warm Superterran     ? - 15.2 - 5.6
# 27   028. KOI-2020.01*  K-Warm Superterran     ? - 13.1 - 4.9
# 28    029. Kepler-26 e  M-Warm Superterran     ? - 12.8 - 4.8
# 29    030. KOI-854.01*  M-Warm Superterran   59.4 - 9.5 - 3.7
# 30    031. Kepler-61 b  K-Warm Superterran     ? - 14.4 - 5.4
# 31   032. KOI-6343.01*  F-Warm Superterran   47.4 - 8.4 - 3.3
# 32   033. KOI-1876.01*  K-Warm Superterran     ? - 18.1 - 6.5
# 33   034. KOI-7470.01*  K-Warm Superterran   47.4 - 8.4 - 3.3
# 34   035. KOI-5276.01*  K-Warm Superterran     ? - 15.2 - 5.6
# 35   036. KOI-7345.01*  F-Warm Superterran     ? - 21.1 - 7.5
# 36   037. KOI-4016.01*  K-Warm Superterran     ? - 18.5 - 6.7
# 37   038. KOI-2834.01*  K-Warm Superterran     ? - 23.6 - 8.2
# 38   039. KOI-4458.01*  F-Warm Superterran     ? - 25.9 - 8.9
# 39   040. Kepler-439 b  G-Warm Superterran     ? - 19.5 - 7.0
# 40   041. KOI-6734.01*  G-Warm Superterran     ? - 13.1 - 4.9
# 41   042. KOI-7136.01*  G-Warm Superterran     ? - 17.4 - 6.3
# 42   043. KOI-3946.01*  F-Warm Superterran     ? - 20.7 - 7.3
# 43   044. KOI-7040.01*  F-Warm Superterran     ? - 14.7 - 5.5
# 44   045. Kepler-309 c  M-Warm Superterran     ? - 12.3 - 4.7
# 45   046. Kepler-441 b  K-Warm Superterran   52.9 - 8.9 - 3.5
# 46   047. KOI-2770.01*  K-Warm Superterran     ? - 18.8 - 6.8
# 47   048. Kepler-186 f       M-Warm Terran    3.3 - 1.1 - 0.5
# 48   049. Kepler-174 d  K-Warm Superterran     ? - 12.6 - 4.8
# 49   050. KOI-4356.01*  K-Warm Superterran   49.2 - 8.6 - 3.4
# 50    051. KOI-959.01*  M-Warm Superterran     ? - 18.8 - 6.8
#
#              radius  flux  teq  period distance   esi
# 0               0.8  1.13  263     4.0       39  0.90
# 1   0.9 - 1.3 - 1.6  1.21  264     5.4       17  0.89
# 2               1.1  1.38  276    35.2      473  0.88
# 3   0.8 - 1.2 - 1.5  1.47  280     9.9       11  0.86
# 4   1.0 - 1.4 - 1.8  1.22  267    18.6       12  0.86
# 5               1.5  1.22  267    34.1      737  0.85
# 6               1.6  1.10  261   122.4     1200  0.83
# 7               1.6  1.11  261   384.8     1402  0.83
# 8               1.4  1.46  280    24.2      181  0.82
# 9   1.1 - 1.5 - 1.9  1.40  276    17.9       14  0.82
# 10  1.2 - 1.7 - 2.2  0.99  254    35.7       16  0.81
# 11              1.5  1.46  280    44.6      137  0.80
# 12              1.8  0.90  248   168.8     1138  0.80
# 13              1.8  0.90  248    92.7     1741  0.79
# 14  1.1 - 1.6 - 2.0  1.51  282   168.1       12  0.78
# 15              1.8  1.34  274    60.9     1196  0.78
# 16  1.3 - 1.8 - 2.3  0.79  239    24.3       38  0.77
# 17                2  1.15  264   106.0      155  0.77
# 18              1.9  1.39  276   259.3     2866  0.76
# 19              1.9  1.43  273   101.1      851  0.75
# 20  1.3 - 1.9 - 2.4  1.23  268    17.4       38  0.75
# 21              2.1  0.83  243    56.1      818  0.74
# 22  1.3 - 1.8 - 2.3  0.68  227   197.8       42  0.74
# 23  1.3 - 1.8 - 2.4  0.66  230    25.6       49  0.73
# 24              2.2  1.27  267    59.9     1063  0.73
# 25              2.2  0.92  250    32.9      111  0.73
# 26              2.1  1.41  277   196.4     2869  0.73
# 27              2.3  1.20  267   198.7     2289  0.72
# 28              2.3  0.89  247   177.7     2540  0.71
# 29              2.4  1.11  261   289.9      619  0.71
# ..              ...   ...  ...     ...      ...   ...
# 21                2  1.41  278   169.1     1872  0.74
# 22              1.8  0.63  227   535.9     3029  0.74
# 23              2.2  1.03  257   366.1      716  0.74
# 24              2.1  1.21  267    92.7     1236  0.73
# 25              2.2  1.21  267   289.9      684  0.73
# 26              2.2  0.87  246   177.7     2711  0.73
# 27              2.1  0.77  239   111.0     1370  0.73
# 28              2.1  1.32  273    46.8     1007  0.73
# 29                2  0.65  228    56.1      907  0.72
# 30              2.2  1.30  272    59.9      970  0.72
# 31              1.9  0.61  225   569.5     2910  0.72
# 32              2.3  0.96  252    82.5     1105  0.72
# 33              1.9  0.60  225   392.5     1568  0.72
# 34              2.2  0.72  235   220.7     2728  0.71
# 35              2.4  1.19  266   377.5     3963  0.71
# 36              2.3  0.76  238   125.4      807  0.70
# 37              2.4  0.94  251   136.2     2213  0.70
# 38              2.5  1.11  262   358.8     2078  0.70
# 39              2.3  1.55  284   178.1     2025  0.68
# 40              2.1  0.50  214   498.3     3708  0.65
# 41              2.3  0.52  217   441.2     3654  0.65
# 42              2.4  1.87  298   308.5     1873  0.64
# 43              2.2  0.48  212   502.2     2626  0.64
# 44              2.1  0.40  203   105.4      803  0.61
# 45              1.9  0.34  194   207.2     1224  0.58
# 46              2.3  0.39  201   205.4     1598  0.58
# 47              1.1  0.25  179   129.9      555  0.57
# 48              2.1  0.34  194   247.4      916  0.57
# 49              1.9  0.29  187   174.5     1311  0.55
# 50              2.3  0.26  181    12.7       35  0.50
#
# [92 rows x 9 columns]

# %%
# Cleaning habitable planet names so that they match the Kepler database
# Need to remove leading number descriptors and trailing *'s
names = []
for h in habitables[habitables.columns[0]]:
    names.append(h[5:].strip('*'))
names
# Out:
# ['TRAPPIST-1 d',
#  'GJ 3323 b',
#  'Kepler-438 b',
#  'Ross 128 b',
#  'GJ 273 b',
#  'Kepler-296 e',
#  'Kepler-62 e',
#  'Kepler-452 b',
#  'K2-72 e',
#  'Wolf 1061 c',
#  'GJ 832 c',
#  'K2-3 d',
#  'Kepler-1544 b',
#  'Kepler-283 c',
#  'tau Cet e',
#  'Kepler-1410 b',
#  'GJ 180 c',
#  'HD 283869 b',
#  'Kepler-1638 b',
#  'Kepler-440 b',
#  'GJ 180 b',
#  'Kepler-705 b',
#  'HD 40307 g',
#  'GJ 163 c',
#  'Kepler-61 b',
#  'K2-18 b',
#  'Kepler-1606 b',
#  'Kepler-1090 b',
#  'Kepler-443 b',
#  'Kepler-22 b',
#  'GJ 422 b',
#  'K2-9 b',
#  'Kepler-1552 b',
#  'Kepler-1540 b',
#  'GJ 3293 d',
#  'Kepler-298 d',
#  'KIC-5522786 b',
#  'Kepler-174 d',
#  'Kepler-296 f',
#  'GJ 682 c',
#  'KOI-4427 b',
#  'Kepler-395 c',
#  'Kepler-438 b',
#  'KOI-7179.01',
#  'KOI-3010.01',
#  'Kepler-442 b',
#  'KOI-463.01',
#  'KOI-4550.01',
#  'Kepler-62 e',
#  'KOI-4036.01',
#  'KOI-6676.01',
#  'Kepler-155 c',
#  'KOI-5475.01',
#  'KOI-5856.01',
#  'Kepler-235 e',
#  'Kepler-436 b',
#  'KOI-7554.01',
#  'KOI-5236.01',
#  'KOI-3282.01',
#  'Kepler-69 c',
#  'KOI-4450.01',
#  'KOI-4103.01',
#  'KOI-4054.01',
#  'KOI-5202.01',
#  'KOI-7587.01',
#  'KOI-1871.01',
#  'Kepler-22 b',
#  'Kepler-443 b',
#  'KOI-2020.01',
#  'Kepler-26 e',
#  'KOI-854.01',
#  'Kepler-61 b',
#  'KOI-6343.01',
#  'KOI-1876.01',
#  'KOI-7470.01',
#  'KOI-5276.01',
#  'KOI-7345.01',
#  'KOI-4016.01',
#  'KOI-2834.01',
#  'KOI-4458.01',
#  'Kepler-439 b',
#  'KOI-6734.01',
#  'KOI-7136.01',
#  'KOI-3946.01',
#  'KOI-7040.01',
#  'Kepler-309 c',
#  'Kepler-441 b',
#  'KOI-2770.01',
#  'Kepler-186 f',
#  'Kepler-174 d',
#  'KOI-4356.01',
#  'KOI-959.01']

# %%
# Match any habitable planet names to the exoplanet database
matches = []
for n in names:
    if n in list(exoplanets.index.values):
        matches.append(n)
matches
# Out:
# ['TRAPPIST-1 d',
#  'GJ 3323 b',
#  'Kepler-438 b',
#  'Ross 128 b',
#  'GJ 273 b',
#  'Kepler-296 e',
#  'Kepler-62 e',
#  'Kepler-452 b',
#  'Wolf 1061 c',
#  'GJ 832 c',
#  'K2-3 d',
#  'Kepler-1544 b',
#  'Kepler-283 c',
#  'tau Cet e',
#  'Kepler-1410 b',
#  'GJ 180 c',
#  'Kepler-1638 b',
#  'Kepler-440 b',
#  'GJ 180 b',
#  'Kepler-705 b',
#  'HD 40307 g',
#  'GJ 163 c',
#  'Kepler-61 b',
#  'K2-18 b',
#  'Kepler-1606 b',
#  'Kepler-1090 b',
#  'Kepler-443 b',
#  'Kepler-22 b',
#  'GJ 422 b',
#  'K2-9 b',
#  'Kepler-1552 b',
#  'Kepler-1540 b',
#  'GJ 3293 d',
#  'Kepler-298 d',
#  'Kepler-174 d',
#  'Kepler-296 f',
#  'GJ 682 c',
#  'Kepler-395 c',
#  'Kepler-438 b',
#  'Kepler-442 b',
#  'Kepler-62 e',
#  'Kepler-155 c',
#  'Kepler-235 e',
#  'Kepler-436 b',
#  'Kepler-69 c',
#  'Kepler-22 b',
#  'Kepler-443 b',
#  'Kepler-26 e',
#  'Kepler-61 b',
#  'Kepler-439 b',
#  'Kepler-309 c',
#  'Kepler-441 b',
#  'Kepler-186 f',
#  'Kepler-174 d']

# %%
# Get data on all the matches
table = exoplanets.loc[matches]
table
# Out:
#               planet_status      mass  mass_error_min  mass_error_max  \
# name
# TRAPPIST-1 d      Confirmed  0.001300        0.000850        0.000850
# GJ 3323 b         Confirmed  0.006360        0.000790        0.000820
# Kepler-438 b      Confirmed       NaN             NaN             NaN
# Ross 128 b        Confirmed  0.004400        0.000660        0.000660
# GJ 273 b          Confirmed  0.009090        0.000820        0.000850
# Kepler-296 e      Confirmed       NaN             NaN             NaN
# Kepler-62 e       Confirmed  0.113000        0.113000        0.000000
# Kepler-452 b      Confirmed       NaN             NaN             NaN
# Wolf 1061 c       Confirmed  0.010700        0.001300        0.001400
# GJ 832 c          Confirmed  0.015732        0.009754        0.009754
# K2-3 d            Confirmed  0.034900        0.011000        0.011000
# Kepler-1544 b     Confirmed       NaN             NaN             NaN
# Kepler-283 c      Confirmed       NaN             NaN             NaN
# tau Cet e         Confirmed  0.012400        0.002000        0.002600
# Kepler-1410 b     Confirmed       NaN             NaN             NaN
# GJ 180 c          Confirmed  0.020137        0.012896        0.011638
# Kepler-1638 b     Confirmed       NaN             NaN             NaN
# Kepler-440 b      Confirmed       NaN             NaN             NaN
# GJ 180 b          Confirmed  0.026115        0.016671        0.011009
# Kepler-705 b      Confirmed       NaN             NaN             NaN
# HD 40307 g        Confirmed  0.022300        0.008200        0.008200
# GJ 163 c          Confirmed  0.022850        0.002800        0.002800
# Kepler-61 b       Confirmed       NaN             NaN             NaN
# K2-18 b           Confirmed  0.025000        0.006010        0.006010
# Kepler-1606 b     Confirmed       NaN             NaN             NaN
# Kepler-1090 b     Confirmed       NaN             NaN             NaN
# Kepler-443 b      Confirmed       NaN             NaN             NaN
# Kepler-22 b       Confirmed  0.110000             inf             NaN
# GJ 422 b          Confirmed  0.031149        0.012582        0.017614
# K2-9 b            Confirmed       NaN             NaN             NaN
# Kepler-1552 b     Confirmed       NaN             NaN             NaN
# Kepler-1540 b     Confirmed       NaN             NaN             NaN
# GJ 3293 d         Confirmed  0.024000        0.003100        0.003100
# Kepler-298 d      Confirmed       NaN             NaN             NaN
# Kepler-174 d      Confirmed       NaN             NaN             NaN
# Kepler-296 f      Confirmed       NaN             NaN             NaN
# GJ 682 c          Confirmed  0.027365        0.014469        0.018243
# Kepler-395 c      Confirmed       NaN             NaN             NaN
# Kepler-438 b      Confirmed       NaN             NaN             NaN
# Kepler-442 b      Confirmed       NaN             NaN             NaN
# Kepler-62 e       Confirmed  0.113000        0.113000        0.000000
# Kepler-155 c      Confirmed       NaN             NaN             NaN
# Kepler-235 e      Confirmed       NaN             NaN             NaN
# Kepler-436 b      Confirmed       NaN             NaN             NaN
# Kepler-69 c       Confirmed       NaN             NaN             NaN
# Kepler-22 b       Confirmed  0.110000             inf             NaN
# Kepler-443 b      Confirmed       NaN             NaN             NaN
# Kepler-26 e       Confirmed       NaN             NaN             NaN
# Kepler-61 b       Confirmed       NaN             NaN             NaN
# Kepler-439 b      Confirmed       NaN             NaN             NaN
# Kepler-309 c      Confirmed       NaN             NaN             NaN
# Kepler-441 b      Confirmed       NaN             NaN             NaN
# Kepler-186 f      Confirmed       NaN             NaN             NaN
# Kepler-174 d      Confirmed       NaN             NaN             NaN
#
#                mass_sini  mass_sini_error_min  mass_sini_error_max    radius  \
# name
# TRAPPIST-1 d         NaN                  NaN                  NaN  0.068900
# GJ 3323 b       0.006360             0.000790             0.000820       NaN
# Kepler-438 b         NaN                  NaN                  NaN  0.099900
# Ross 128 b      0.004400             0.000660             0.000660       NaN
# GJ 273 b        0.009090             0.000820             0.000850       NaN
# Kepler-296 e         NaN                  NaN                  NaN  0.156000
# Kepler-62 e          NaN                  NaN                  NaN  0.144000
# Kepler-452 b         NaN                  NaN                  NaN  0.145000
# Wolf 1061 c     0.010700             0.001300             0.001400       NaN
# GJ 832 c        0.015732             0.009754             0.009754       NaN
# K2-3 d          0.034900             0.011000             0.011000  0.135000
# Kepler-1544 b        NaN                  NaN                  NaN  0.159000
# Kepler-283 c         NaN                  NaN                  NaN  0.162000
# tau Cet e       0.012400             0.002000             0.002600       NaN
# Kepler-1410 b        NaN                  NaN                  NaN  0.159000
# GJ 180 c        0.020137             0.012896             0.011638       NaN
# Kepler-1638 b        NaN                  NaN                  NaN  0.167000
# Kepler-440 b         NaN                  NaN                  NaN  0.166000
# GJ 180 b        0.026115             0.016671             0.011009       NaN
# Kepler-705 b         NaN                  NaN                  NaN  0.188000
# HD 40307 g      0.022300             0.008200             0.008200       NaN
# GJ 163 c        0.022850             0.002800             0.002800       NaN
# Kepler-61 b          NaN                  NaN                  NaN  0.192000
# K2-18 b         0.025000             0.006010             0.006010  0.200000
# Kepler-1606 b        NaN                  NaN                  NaN  0.185000
# Kepler-1090 b        NaN                  NaN                  NaN  0.201000
# Kepler-443 b         NaN                  NaN                  NaN  0.208000
# Kepler-22 b          NaN                  NaN                  NaN  0.210000
# GJ 422 b        0.031149             0.012582             0.017614       NaN
# K2-9 b               NaN                  NaN                  NaN  0.143000
# Kepler-1552 b        NaN                  NaN                  NaN  0.220000
# Kepler-1540 b        NaN                  NaN                  NaN  0.222000
# GJ 3293 d       0.024000             0.003100             0.003100       NaN
# Kepler-298 d         NaN                  NaN                  NaN  0.223000
# Kepler-174 d         NaN                  NaN                  NaN  0.195000
# Kepler-296 f         NaN                  NaN                  NaN  0.160000
# GJ 682 c        0.027365             0.014469             0.018243       NaN
# Kepler-395 c         NaN                  NaN                  NaN  0.118000
# Kepler-438 b         NaN                  NaN                  NaN  0.099900
# Kepler-442 b         NaN                  NaN                  NaN  0.120000
# Kepler-62 e          NaN                  NaN                  NaN  0.144000
# Kepler-155 c         NaN                  NaN                  NaN  0.200000
# Kepler-235 e         NaN                  NaN                  NaN  0.198000
# Kepler-436 b         NaN                  NaN                  NaN  0.244000
# Kepler-69 c          NaN                  NaN                  NaN  0.153000
# Kepler-22 b          NaN                  NaN                  NaN  0.210000
# Kepler-443 b         NaN                  NaN                  NaN  0.208000
# Kepler-26 e          NaN                  NaN                  NaN  0.215000
# Kepler-61 b          NaN                  NaN                  NaN  0.192000
# Kepler-439 b         NaN                  NaN                  NaN  0.200000
# Kepler-309 c         NaN                  NaN                  NaN  0.224000
# Kepler-441 b         NaN                  NaN                  NaN  0.146000
# Kepler-186 f         NaN                  NaN                  NaN  0.099028
# Kepler-174 d         NaN                  NaN                  NaN  0.195000
#
#                radius_error_min  radius_error_max           ...             \
# name                                                        ...
# TRAPPIST-1 d           0.002700           0.00270           ...
# GJ 3323 b                   NaN               NaN           ...
# Kepler-438 b           0.015000           0.01500           ...
# Ross 128 b                  NaN               NaN           ...
# GJ 273 b                    NaN               NaN           ...
# Kepler-296 e           0.021000           0.02100           ...
# Kepler-62 e            0.004500           0.00450           ...
# Kepler-452 b           0.020000           0.02100           ...
# Wolf 1061 c                 NaN               NaN           ...
# GJ 832 c                    NaN               NaN           ...
# K2-3 d                 0.021000           0.02100           ...
# Kepler-1544 b          0.006000           0.00800           ...
# Kepler-283 c           0.011000           0.01100           ...
# tau Cet e                   NaN               NaN           ...
# Kepler-1410 b          0.012000           0.01100           ...
# GJ 180 c                    NaN               NaN           ...
# Kepler-1638 b          0.020000           0.02900           ...
# Kepler-440 b           0.021000           0.01700           ...
# GJ 180 b                    NaN               NaN           ...
# Kepler-705 b           0.007000           0.00900           ...
# HD 40307 g                  NaN               NaN           ...
# GJ 163 c                    NaN               NaN           ...
# Kepler-61 b            0.011600           0.01160           ...
# K2-18 b                0.021000           0.02100           ...
# Kepler-1606 b          0.013000           0.02100           ...
# Kepler-1090 b          0.015000           0.01900           ...
# Kepler-443 b           0.018000           0.01800           ...
# Kepler-22 b            0.012000           0.01200           ...
# GJ 422 b                    NaN               NaN           ...
# K2-9 b                 0.037000           0.03700           ...
# Kepler-1552 b          0.009000           0.01000           ...
# Kepler-1540 b          0.012000           0.01700           ...
# GJ 3293 d                   NaN               NaN           ...
# Kepler-298 d           0.018000           0.01800           ...
# Kepler-174 d           0.012000           0.01200           ...
# Kepler-296 f           0.010000           0.01000           ...
# GJ 682 c                    NaN               NaN           ...
# Kepler-395 c           0.008000           0.00800           ...
# Kepler-438 b           0.015000           0.01500           ...
# Kepler-442 b           0.009800           0.01600           ...
# Kepler-62 e            0.004500           0.00450           ...
# Kepler-155 c           0.013000           0.01300           ...
# Kepler-235 e           0.026000           0.02600           ...
# Kepler-436 b           0.021000           0.02100           ...
# Kepler-69 c            0.021000           0.03000           ...
# Kepler-22 b            0.012000           0.01200           ...
# Kepler-443 b           0.018000           0.01800           ...
# Kepler-26 e            0.013000           0.01300           ...
# Kepler-61 b            0.011600           0.01160           ...
# Kepler-439 b           0.014000           0.04000           ...
# Kepler-309 c           0.016000           0.01600           ...
# Kepler-441 b           0.021000           0.02100           ...
# Kepler-186 f           0.011598           0.01249           ...
# Kepler-174 d           0.012000           0.01200           ...
#
#                star_sp_type  star_age  star_age_error_min  star_age_error_max  \
# name
# TRAPPIST-1 d             M8       0.5                 NaN                 NaN
# GJ 3323 b                M4       NaN                 NaN                 NaN
# Kepler-438 b            NaN       4.4            0.800000            0.700000
# Ross 128 b               M4       5.0                 NaN                 NaN
# GJ 273 b               M3.5       NaN                 NaN                 NaN
# Kepler-296 e            NaN       NaN                 NaN                 NaN
# Kepler-62 e             K2V       NaN                 NaN                 NaN
# Kepler-452 b             G2       6.0            2.000000            2.000000
# Wolf 1061 c             M3V       NaN                 NaN                 NaN
# GJ 832 c                NaN       NaN                 NaN                 NaN
# K2-3 d                M0.0V       1.0                 inf                 NaN
# Kepler-1544 b           NaN       NaN                 NaN                 NaN
# Kepler-283 c            NaN       NaN                 NaN                 NaN
# tau Cet e            G8.5 V       5.8                 NaN                 NaN
# Kepler-1410 b           NaN       NaN                 NaN                 NaN
# GJ 180 c                M2V       NaN                 NaN                 NaN
# Kepler-1638 b           NaN       NaN                 NaN                 NaN
# Kepler-440 b            NaN       1.3            0.600000            0.200000
# GJ 180 b                M2V       NaN                 NaN                 NaN
# Kepler-705 b            NaN       NaN                 NaN                 NaN
# HD 40307 g            K2.5V       NaN                 NaN                 NaN
# GJ 163 c               M3.5       3.0            2.000000            7.000000
# Kepler-61 b             K7V       1.0            0.000000                 inf
# K2-18 b                 NaN       NaN                 NaN                 NaN
# Kepler-1606 b           NaN       NaN                 NaN                 NaN
# Kepler-1090 b           NaN       NaN                 NaN                 NaN
# Kepler-443 b            NaN       3.2            7.300000            0.400000
# Kepler-22 b              G5       NaN                 NaN                 NaN
# GJ 422 b              M3.5V       NaN                 NaN                 NaN
# K2-9 b                  NaN       NaN                 NaN                 NaN
# Kepler-1552 b           NaN       NaN                 NaN                 NaN
# Kepler-1540 b           NaN       NaN                 NaN                 NaN
# GJ 3293 d              M2.5       NaN                 NaN                 NaN
# Kepler-298 d            NaN       NaN                 NaN                 NaN
# Kepler-174 d            NaN       NaN                 NaN                 NaN
# Kepler-296 f            NaN       NaN                 NaN                 NaN
# GJ 682 c              M3.5V       NaN                 NaN                 NaN
# Kepler-395 c            NaN       NaN                 NaN                 NaN
# Kepler-438 b            NaN       4.4            0.800000            0.700000
# Kepler-442 b            NaN       2.9            8.100000            0.200000
# Kepler-62 e             K2V       NaN                 NaN                 NaN
# Kepler-155 c            NaN       NaN                 NaN                 NaN
# Kepler-235 e            NaN       NaN                 NaN                 NaN
# Kepler-436 b            NaN       3.0            7.700000            0.300000
# Kepler-69 c             G4V       NaN                 NaN                 NaN
# Kepler-22 b              G5       NaN                 NaN                 NaN
# Kepler-443 b            NaN       3.2            7.300000            0.400000
# Kepler-26 e             NaN       NaN                 NaN                 NaN
# Kepler-61 b             K7V       1.0            0.000000                 inf
# Kepler-439 b            NaN       7.2            3.900000            3.900000
# Kepler-309 c            NaN       NaN                 NaN                 NaN
# Kepler-441 b            NaN       1.9            0.500000            0.500000
# Kepler-186 f            NaN       NaN                 NaN                 NaN
# Kepler-174 d            NaN       NaN                 NaN                 NaN
#
#                star_teff  star_teff_error_min  star_teff_error_max  \
# name
# TRAPPIST-1 d      2550.0                55.00                55.00
# GJ 3323 b         3159.0                49.00                49.00
# Kepler-438 b      3748.0               112.00               112.00
# Ross 128 b        3192.0                60.00                60.00
# GJ 273 b          3382.0                49.00                49.00
# Kepler-296 e      4249.0               100.00               100.00
# Kepler-62 e       4869.0                  NaN                  NaN
# Kepler-452 b      5757.0                85.00                85.00
# Wolf 1061 c       3342.0                49.00                49.00
# GJ 832 c             NaN                  NaN                  NaN
# K2-3 d            3951.0                38.00                33.00
# Kepler-1544 b     4886.0                56.64                73.93
# Kepler-283 c      4351.0               100.00               100.00
# tau Cet e         5344.0                50.00                50.00
# Kepler-1410 b     4092.0                77.85               100.24
# GJ 180 c          3371.0                  NaN                  NaN
# Kepler-1638 b     5710.0               111.43                96.70
# Kepler-440 b      4134.0               154.00               154.00
# GJ 180 b          3371.0                  NaN                  NaN
# Kepler-705 b      3722.0                32.88                29.96
# HD 40307 g        4977.0                59.00                59.00
# GJ 163 c             NaN                  NaN                  NaN
# Kepler-61 b       4017.0               150.00                68.00
# K2-18 b           3503.0                60.00                60.00
# Kepler-1606 b     5422.0                63.50                59.86
# Kepler-1090 b     5321.0               145.36               147.76
# Kepler-443 b      4723.0               100.00               100.00
# Kepler-22 b       5518.0                44.00                44.00
# GJ 422 b          3323.0                  NaN                  NaN
# K2-9 b            3468.0                19.00                20.00
# Kepler-1552 b     5202.0                75.40                85.40
# Kepler-1540 b     4540.0                88.20                69.37
# GJ 3293 d         3466.0                49.00                49.00
# Kepler-298 d      4465.0               100.00               100.00
# Kepler-174 d      4880.0               126.00               126.00
# Kepler-296 f      4249.0               100.00               100.00
# GJ 682 c          3028.0                  NaN                  NaN
# Kepler-395 c      4262.0               100.00               100.00
# Kepler-438 b      3748.0               112.00               112.00
# Kepler-442 b      4402.0               100.00               100.00
# Kepler-62 e       4869.0                  NaN                  NaN
# Kepler-155 c      4508.0               100.00               100.00
# Kepler-235 e      4255.0               100.00               100.00
# Kepler-436 b      4551.0               100.00               100.00
# Kepler-69 c       5638.0               168.00               168.00
# Kepler-22 b       5518.0                44.00                44.00
# Kepler-443 b      4723.0               100.00               100.00
# Kepler-26 e       4500.0               100.00               100.00
# Kepler-61 b       4017.0               150.00                68.00
# Kepler-439 b      5431.0               100.00               100.00
# Kepler-309 c      4713.0               100.00               100.00
# Kepler-441 b      4340.0               177.00               177.00
# Kepler-186 f      3788.0                54.00                54.00
# Kepler-174 d      4880.0               126.00               126.00
#
#                star_detected_disc  star_magnetic_field  \
# name
# TRAPPIST-1 d                  NaN                  NaN
# GJ 3323 b                     NaN                  NaN
# Kepler-438 b                  NaN                  NaN
# Ross 128 b                    NaN                  NaN
# GJ 273 b                      NaN                  NaN
# Kepler-296 e                  NaN                  NaN
# Kepler-62 e                   NaN                  NaN
# Kepler-452 b                  NaN                  NaN
# Wolf 1061 c                   NaN                  NaN
# GJ 832 c                      NaN                  NaN
# K2-3 d                        NaN                  NaN
# Kepler-1544 b                 NaN                  NaN
# Kepler-283 c                  NaN                  NaN
# tau Cet e                 Imaging                  NaN
# Kepler-1410 b                 NaN                  NaN
# GJ 180 c                      NaN                  NaN
# Kepler-1638 b                 NaN                  NaN
# Kepler-440 b                  NaN                  NaN
# GJ 180 b                      NaN                  NaN
# Kepler-705 b                  NaN                  NaN
# HD 40307 g              IR Excess                  NaN
# GJ 163 c                      NaN                  NaN
# Kepler-61 b                   NaN                  NaN
# K2-18 b                       NaN                  NaN
# Kepler-1606 b                 NaN                  NaN
# Kepler-1090 b                 NaN                  NaN
# Kepler-443 b                  NaN                  NaN
# Kepler-22 b                   NaN                  NaN
# GJ 422 b                      NaN                  NaN
# K2-9 b                        NaN                  NaN
# Kepler-1552 b                 NaN                  NaN
# Kepler-1540 b                 NaN                  NaN
# GJ 3293 d                     NaN                  NaN
# Kepler-298 d                  NaN                  NaN
# Kepler-174 d                  NaN                  NaN
# Kepler-296 f                  NaN                  NaN
# GJ 682 c                      NaN                  NaN
# Kepler-395 c                  NaN                  NaN
# Kepler-438 b                  NaN                  NaN
# Kepler-442 b                  NaN                  NaN
# Kepler-62 e                   NaN                  NaN
# Kepler-155 c                  NaN                  NaN
# Kepler-235 e                  NaN                  NaN
# Kepler-436 b                  NaN                  NaN
# Kepler-69 c                   NaN                  NaN
# Kepler-22 b                   NaN                  NaN
# Kepler-443 b                  NaN                  NaN
# Kepler-26 e                   NaN                  NaN
# Kepler-61 b                   NaN                  NaN
# Kepler-439 b                  NaN                  NaN
# Kepler-309 c                  NaN                  NaN
# Kepler-441 b                  NaN                  NaN
# Kepler-186 f                  NaN                  NaN
# Kepler-174 d                  NaN                  NaN
#
#                   star_alternate_names
# name
# TRAPPIST-1 d   2MASS J23062928-0502285
# GJ 3323 b                          NaN
# Kepler-438 b                       NaN
# Ross 128 b                         NaN
# GJ 273 b                           NaN
# Kepler-296 e                       NaN
# Kepler-62 e                        NaN
# Kepler-452 b                       NaN
# Wolf 1061 c                     GJ 628
# GJ 832 c                           NaN
# K2-3 d                 EPIC 201367065
# Kepler-1544 b                      NaN
# Kepler-283 c                       NaN
# tau Cet e                          NaN
# Kepler-1410 b                      NaN
# GJ 180 c                           NaN
# Kepler-1638 b                      NaN
# Kepler-440 b                       NaN
# GJ 180 b                           NaN
# Kepler-705 b                       NaN
# HD 40307 g                         NaN
# GJ 163 c                           NaN
# Kepler-61 b                        NaN
# K2-18 b                 EPIC 201912552
# Kepler-1606 b                      NaN
# Kepler-1090 b                      NaN
# Kepler-443 b                       NaN
# Kepler-22 b                        NaN
# GJ 422 b                           NaN
# K2-9 b                  EPIC 201465501
# Kepler-1552 b                      NaN
# Kepler-1540 b                      NaN
# GJ 3293 d                          NaN
# Kepler-298 d                       NaN
# Kepler-174 d                       NaN
# Kepler-296 f                       NaN
# GJ 682 c                           NaN
# Kepler-395 c                       NaN
# Kepler-438 b                       NaN
# Kepler-442 b                       NaN
# Kepler-62 e                        NaN
# Kepler-155 c                       NaN
# Kepler-235 e                       NaN
# Kepler-436 b                       NaN
# Kepler-69 c                        NaN
# Kepler-22 b                        NaN
# Kepler-443 b                       NaN
# Kepler-26 e                        NaN
# Kepler-61 b                        NaN
# Kepler-439 b                       NaN
# Kepler-309 c                       NaN
# Kepler-441 b                       NaN
# Kepler-186 f                       NaN
# Kepler-174 d                       NaN
#
# [54 rows x 97 columns]

# %%
# Connecting to local database
rds_connection_string = "<insert user name>:<insert password>@localhost:5432/exoplanets"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
# Loading json converted DataFrame into database
table.to_sql(name='Habitable_planets', con=engine, if_exists='append', index=False)
